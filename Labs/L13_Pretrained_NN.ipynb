# %% [markdown]
# # CSE 572: Lab 13
#
# In this lab, you will practice implementing techniques for dimensionality reduction using features extracted by pre-trained neural networks and classification with transfer learning.
#
# To execute and make changes to this notebook, click File > Save a copy to save your own version in your Google Drive or Github. Read the step-by-step instructions below carefully. To execute the code, click on each cell below and press the SHIFT-ENTER keys simultaneously or by clicking the Play button.
#
# When you finish executing all code/exercises, save your notebook then download a copy (.ipynb file). Submit the following **three** things:
# 1. a link to your Colab notebook,
# 2. the .ipynb file, and
# 3. a pdf of the executed notebook on Canvas.
#
# To generate a pdf of the notebook, click File > Print > Save as PDF.

# %% [markdown]
# ## Load the dataset
#
# We will use the same “Labeled Faces in the Wild” (LFW) [dataset](http://vis-www.cs.umass.edu/lfw/) that we used in Labs 11 and 12 for this lab. Since we are going to use neural networks pre-trained using the ImageNet database which has RGB color images, we will load in the images in color rather than grayscale format (`color=True`) and keep the original image size (`resize=1.0`).

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.datasets import fetch_lfw_people

lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=1.0, color=True)

# data attribute gives the data matrix with the image dimension flattened
X = lfw_people.data
print('Num samples: {}'.format(X.shape[0]))
print('Num features: {}'.format(X.shape[1]))

# images attribute gives the unflattened image dimension
print('Image dimensions: {} x {}'.format(lfw_people.images.shape[1], lfw_people.images.shape[2]))

# the label to predict is the id of the person
y = lfw_people.target
# target_names attribute tells us the name of the person associated with each id
target_names = lfw_people.target_names
n_classes = target_names.shape[0]
print('Num classes: {}'.format(n_classes))
print('Class names:', target_names)
# Out:
# Num samples: 1288
# Num features: 35250
# Image dimensions: 125 x 94
# Num classes: 7
# Class names: ['Ariel Sharon' 'Colin Powell' 'Donald Rumsfeld' 'George W Bush'
#  'Gerhard Schroeder' 'Hugo Chavez' 'Tony Blair']

# %% [markdown]
# The dataset has 1,288 images of the faces of 7 different people. The code below prints the number of samples from each class.

# %%
for i in range(n_classes):
    print('Number of instances in class {} ({}): {}'.format(i,
                                                            target_names[i],
                                                            y[y==i].shape[0]
                                                           ))
# Out:
# Number of instances in class 0 (Ariel Sharon): 77
# Number of instances in class 1 (Colin Powell): 236
# Number of instances in class 2 (Donald Rumsfeld): 121
# Number of instances in class 3 (George W Bush): 530
# Number of instances in class 4 (Gerhard Schroeder): 109
# Number of instances in class 5 (Hugo Chavez): 71
# Number of instances in class 6 (Tony Blair): 144

# %% [markdown]
# To get an idea of what is in our dataset, we visualize a random face from each class below. (Note: You can run this cell many times to see different random examples.)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(ncols=n_classes, figsize=(13,6))

for i in range(n_classes):
    rand_ind = np.random.randint(0, y[y==i].shape[0])
    axes[i].imshow(lfw_people.images[y==i][rand_ind].astype(np.uint8))
    axes[i].axis('off')
    axes[i].set_title(target_names[i])

# %% [markdown]
# Next, we will split the data into training and test subsets, using 30\% of the data for testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# Next we standardize the data so that the mean of all attributes is 0 using the StandardScaler() object in scikit-learn to standardize the data. We fit the scaler to the training data and apply it to both the training and test data.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Feature extraction with pre-trained network
#
# One approach for non-linear dimensionality reduction is to extract features using a pre-trained neural network. The network is typically a large architecture that has shown state of the art performance for the pre-training task using a large dataset, in this case ImageNet. We will use the InceptionV3 model pre-trained with ImageNet for our feature extractor.
#
# Note that we pass the `include_top=False` argument to get the InceptionV3 architecture *without* the final classification layer so that the output will be the last hidden layer of the model.

# %%
import tensorflow as tf

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input

# Set the random seed for reproducibility
seed = 0
tf.random.set_seed(seed)

# %%
base_model = InceptionV3(weights='imagenet', include_top=False)

base_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_470 (Conv2D)            (None, None, None,   864         ['input_6[0][0]']
#                                 32)
#
#  batch_normalization_470 (Batch  (None, None, None,   96         ['conv2d_470[0][0]']
#  Normalization)                 32)
#
#  activation_470 (Activation)    (None, None, None,   0           ['batch_normalization_470[0][0]']
#                                 32)
#
#  conv2d_471 (Conv2D)            (None, None, None,   9216        ['activation_470[0][0]']
#                                 32)
#
#  batch_normalization_471 (Batch  (None, None, None,   96         ['conv2d_471[0][0]']
#  Normalization)                 32)
#
#  activation_471 (Activation)    (None, None, None,   0           ['batch_normalization_471[0][0]']
#                                 32)
#
#  conv2d_472 (Conv2D)            (None, None, None,   18432       ['activation_471[0][0]']
#                                 64)
#
#  batch_normalization_472 (Batch  (None, None, None,   192        ['conv2d_472[0][0]']
#  Normalization)                 64)
#
#  activation_472 (Activation)    (None, None, None,   0           ['batch_normalization_472[0][0]']
#                                 64)
#
#  max_pooling2d_20 (MaxPooling2D  (None, None, None,   0          ['activation_472[0][0]']
#  )                              64)
#
#  conv2d_473 (Conv2D)            (None, None, None,   5120        ['max_pooling2d_20[0][0]']
#                                 80)
#
#  batch_normalization_473 (Batch  (None, None, None,   240        ['conv2d_473[0][0]']
#  Normalization)                 80)
#
#  activation_473 (Activation)    (None, None, None,   0           ['batch_normalization_473[0][0]']
#                                 80)
#
#  conv2d_474 (Conv2D)            (None, None, None,   138240      ['activation_473[0][0]']
#                                 192)
#
#  batch_normalization_474 (Batch  (None, None, None,   576        ['conv2d_474[0][0]']
#  Normalization)                 192)
#
#  activation_474 (Activation)    (None, None, None,   0           ['batch_normalization_474[0][0]']
#                                 192)
#
#  max_pooling2d_21 (MaxPooling2D  (None, None, None,   0          ['activation_474[0][0]']
#  )                              192)
#
#  conv2d_478 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_21[0][0]']
#                                 64)
#
#  batch_normalization_478 (Batch  (None, None, None,   192        ['conv2d_478[0][0]']
#  Normalization)                 64)
#
#  activation_478 (Activation)    (None, None, None,   0           ['batch_normalization_478[0][0]']
#                                 64)
#
#  conv2d_476 (Conv2D)            (None, None, None,   9216        ['max_pooling2d_21[0][0]']
#                                 48)
#
#  conv2d_479 (Conv2D)            (None, None, None,   55296       ['activation_478[0][0]']
#                                 96)
#
#  batch_normalization_476 (Batch  (None, None, None,   144        ['conv2d_476[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_479 (Batch  (None, None, None,   288        ['conv2d_479[0][0]']
#  Normalization)                 96)
#
#  activation_476 (Activation)    (None, None, None,   0           ['batch_normalization_476[0][0]']
#                                 48)
#
#  activation_479 (Activation)    (None, None, None,   0           ['batch_normalization_479[0][0]']
#                                 96)
#
#  average_pooling2d_45 (AverageP  (None, None, None,   0          ['max_pooling2d_21[0][0]']
#  ooling2D)                      192)
#
#  conv2d_475 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_21[0][0]']
#                                 64)
#
#  conv2d_477 (Conv2D)            (None, None, None,   76800       ['activation_476[0][0]']
#                                 64)
#
#  conv2d_480 (Conv2D)            (None, None, None,   82944       ['activation_479[0][0]']
#                                 96)
#
#  conv2d_481 (Conv2D)            (None, None, None,   6144        ['average_pooling2d_45[0][0]']
#                                 32)
#
#  batch_normalization_475 (Batch  (None, None, None,   192        ['conv2d_475[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_477 (Batch  (None, None, None,   192        ['conv2d_477[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_480 (Batch  (None, None, None,   288        ['conv2d_480[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_481 (Batch  (None, None, None,   96         ['conv2d_481[0][0]']
#  Normalization)                 32)
#
#  activation_475 (Activation)    (None, None, None,   0           ['batch_normalization_475[0][0]']
#                                 64)
#
#  activation_477 (Activation)    (None, None, None,   0           ['batch_normalization_477[0][0]']
#                                 64)
#
#  activation_480 (Activation)    (None, None, None,   0           ['batch_normalization_480[0][0]']
#                                 96)
#
#  activation_481 (Activation)    (None, None, None,   0           ['batch_normalization_481[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_475[0][0]',
#                                 256)                              'activation_477[0][0]',
#                                                                   'activation_480[0][0]',
#                                                                   'activation_481[0][0]']
#
#  conv2d_485 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_485 (Batch  (None, None, None,   192        ['conv2d_485[0][0]']
#  Normalization)                 64)
#
#  activation_485 (Activation)    (None, None, None,   0           ['batch_normalization_485[0][0]']
#                                 64)
#
#  conv2d_483 (Conv2D)            (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_486 (Conv2D)            (None, None, None,   55296       ['activation_485[0][0]']
#                                 96)
#
#  batch_normalization_483 (Batch  (None, None, None,   144        ['conv2d_483[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_486 (Batch  (None, None, None,   288        ['conv2d_486[0][0]']
#  Normalization)                 96)
#
#  activation_483 (Activation)    (None, None, None,   0           ['batch_normalization_483[0][0]']
#                                 48)
#
#  activation_486 (Activation)    (None, None, None,   0           ['batch_normalization_486[0][0]']
#                                 96)
#
#  average_pooling2d_46 (AverageP  (None, None, None,   0          ['mixed0[0][0]']
#  ooling2D)                      256)
#
#  conv2d_482 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_484 (Conv2D)            (None, None, None,   76800       ['activation_483[0][0]']
#                                 64)
#
#  conv2d_487 (Conv2D)            (None, None, None,   82944       ['activation_486[0][0]']
#                                 96)
#
#  conv2d_488 (Conv2D)            (None, None, None,   16384       ['average_pooling2d_46[0][0]']
#                                 64)
#
#  batch_normalization_482 (Batch  (None, None, None,   192        ['conv2d_482[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_484 (Batch  (None, None, None,   192        ['conv2d_484[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_487 (Batch  (None, None, None,   288        ['conv2d_487[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_488 (Batch  (None, None, None,   192        ['conv2d_488[0][0]']
#  Normalization)                 64)
#
#  activation_482 (Activation)    (None, None, None,   0           ['batch_normalization_482[0][0]']
#                                 64)
#
#  activation_484 (Activation)    (None, None, None,   0           ['batch_normalization_484[0][0]']
#                                 64)
#
#  activation_487 (Activation)    (None, None, None,   0           ['batch_normalization_487[0][0]']
#                                 96)
#
#  activation_488 (Activation)    (None, None, None,   0           ['batch_normalization_488[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_482[0][0]',
#                                 288)                              'activation_484[0][0]',
#                                                                   'activation_487[0][0]',
#                                                                   'activation_488[0][0]']
#
#  conv2d_492 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_492 (Batch  (None, None, None,   192        ['conv2d_492[0][0]']
#  Normalization)                 64)
#
#  activation_492 (Activation)    (None, None, None,   0           ['batch_normalization_492[0][0]']
#                                 64)
#
#  conv2d_490 (Conv2D)            (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_493 (Conv2D)            (None, None, None,   55296       ['activation_492[0][0]']
#                                 96)
#
#  batch_normalization_490 (Batch  (None, None, None,   144        ['conv2d_490[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_493 (Batch  (None, None, None,   288        ['conv2d_493[0][0]']
#  Normalization)                 96)
#
#  activation_490 (Activation)    (None, None, None,   0           ['batch_normalization_490[0][0]']
#                                 48)
#
#  activation_493 (Activation)    (None, None, None,   0           ['batch_normalization_493[0][0]']
#                                 96)
#
#  average_pooling2d_47 (AverageP  (None, None, None,   0          ['mixed1[0][0]']
#  ooling2D)                      288)
#
#  conv2d_489 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_491 (Conv2D)            (None, None, None,   76800       ['activation_490[0][0]']
#                                 64)
#
#  conv2d_494 (Conv2D)            (None, None, None,   82944       ['activation_493[0][0]']
#                                 96)
#
#  conv2d_495 (Conv2D)            (None, None, None,   18432       ['average_pooling2d_47[0][0]']
#                                 64)
#
#  batch_normalization_489 (Batch  (None, None, None,   192        ['conv2d_489[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_491 (Batch  (None, None, None,   192        ['conv2d_491[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_494 (Batch  (None, None, None,   288        ['conv2d_494[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_495 (Batch  (None, None, None,   192        ['conv2d_495[0][0]']
#  Normalization)                 64)
#
#  activation_489 (Activation)    (None, None, None,   0           ['batch_normalization_489[0][0]']
#                                 64)
#
#  activation_491 (Activation)    (None, None, None,   0           ['batch_normalization_491[0][0]']
#                                 64)
#
#  activation_494 (Activation)    (None, None, None,   0           ['batch_normalization_494[0][0]']
#                                 96)
#
#  activation_495 (Activation)    (None, None, None,   0           ['batch_normalization_495[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_489[0][0]',
#                                 288)                              'activation_491[0][0]',
#                                                                   'activation_494[0][0]',
#                                                                   'activation_495[0][0]']
#
#  conv2d_497 (Conv2D)            (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_497 (Batch  (None, None, None,   192        ['conv2d_497[0][0]']
#  Normalization)                 64)
#
#  activation_497 (Activation)    (None, None, None,   0           ['batch_normalization_497[0][0]']
#                                 64)
#
#  conv2d_498 (Conv2D)            (None, None, None,   55296       ['activation_497[0][0]']
#                                 96)
#
#  batch_normalization_498 (Batch  (None, None, None,   288        ['conv2d_498[0][0]']
#  Normalization)                 96)
#
#  activation_498 (Activation)    (None, None, None,   0           ['batch_normalization_498[0][0]']
#                                 96)
#
#  conv2d_496 (Conv2D)            (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_499 (Conv2D)            (None, None, None,   82944       ['activation_498[0][0]']
#                                 96)
#
#  batch_normalization_496 (Batch  (None, None, None,   1152       ['conv2d_496[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_499 (Batch  (None, None, None,   288        ['conv2d_499[0][0]']
#  Normalization)                 96)
#
#  activation_496 (Activation)    (None, None, None,   0           ['batch_normalization_496[0][0]']
#                                 384)
#
#  activation_499 (Activation)    (None, None, None,   0           ['batch_normalization_499[0][0]']
#                                 96)
#
#  max_pooling2d_22 (MaxPooling2D  (None, None, None,   0          ['mixed2[0][0]']
#  )                              288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_496[0][0]',
#                                 768)                              'activation_499[0][0]',
#                                                                   'max_pooling2d_22[0][0]']
#
#  conv2d_504 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_504 (Batch  (None, None, None,   384        ['conv2d_504[0][0]']
#  Normalization)                 128)
#
#  activation_504 (Activation)    (None, None, None,   0           ['batch_normalization_504[0][0]']
#                                 128)
#
#  conv2d_505 (Conv2D)            (None, None, None,   114688      ['activation_504[0][0]']
#                                 128)
#
#  batch_normalization_505 (Batch  (None, None, None,   384        ['conv2d_505[0][0]']
#  Normalization)                 128)
#
#  activation_505 (Activation)    (None, None, None,   0           ['batch_normalization_505[0][0]']
#                                 128)
#
#  conv2d_501 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_506 (Conv2D)            (None, None, None,   114688      ['activation_505[0][0]']
#                                 128)
#
#  batch_normalization_501 (Batch  (None, None, None,   384        ['conv2d_501[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_506 (Batch  (None, None, None,   384        ['conv2d_506[0][0]']
#  Normalization)                 128)
#
#  activation_501 (Activation)    (None, None, None,   0           ['batch_normalization_501[0][0]']
#                                 128)
#
#  activation_506 (Activation)    (None, None, None,   0           ['batch_normalization_506[0][0]']
#                                 128)
#
#  conv2d_502 (Conv2D)            (None, None, None,   114688      ['activation_501[0][0]']
#                                 128)
#
#  conv2d_507 (Conv2D)            (None, None, None,   114688      ['activation_506[0][0]']
#                                 128)
#
#  batch_normalization_502 (Batch  (None, None, None,   384        ['conv2d_502[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_507 (Batch  (None, None, None,   384        ['conv2d_507[0][0]']
#  Normalization)                 128)
#
#  activation_502 (Activation)    (None, None, None,   0           ['batch_normalization_502[0][0]']
#                                 128)
#
#  activation_507 (Activation)    (None, None, None,   0           ['batch_normalization_507[0][0]']
#                                 128)
#
#  average_pooling2d_48 (AverageP  (None, None, None,   0          ['mixed3[0][0]']
#  ooling2D)                      768)
#
#  conv2d_500 (Conv2D)            (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_503 (Conv2D)            (None, None, None,   172032      ['activation_502[0][0]']
#                                 192)
#
#  conv2d_508 (Conv2D)            (None, None, None,   172032      ['activation_507[0][0]']
#                                 192)
#
#  conv2d_509 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_48[0][0]']
#                                 192)
#
#  batch_normalization_500 (Batch  (None, None, None,   576        ['conv2d_500[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_503 (Batch  (None, None, None,   576        ['conv2d_503[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_508 (Batch  (None, None, None,   576        ['conv2d_508[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_509 (Batch  (None, None, None,   576        ['conv2d_509[0][0]']
#  Normalization)                 192)
#
#  activation_500 (Activation)    (None, None, None,   0           ['batch_normalization_500[0][0]']
#                                 192)
#
#  activation_503 (Activation)    (None, None, None,   0           ['batch_normalization_503[0][0]']
#                                 192)
#
#  activation_508 (Activation)    (None, None, None,   0           ['batch_normalization_508[0][0]']
#                                 192)
#
#  activation_509 (Activation)    (None, None, None,   0           ['batch_normalization_509[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_500[0][0]',
#                                 768)                              'activation_503[0][0]',
#                                                                   'activation_508[0][0]',
#                                                                   'activation_509[0][0]']
#
#  conv2d_514 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_514 (Batch  (None, None, None,   480        ['conv2d_514[0][0]']
#  Normalization)                 160)
#
#  activation_514 (Activation)    (None, None, None,   0           ['batch_normalization_514[0][0]']
#                                 160)
#
#  conv2d_515 (Conv2D)            (None, None, None,   179200      ['activation_514[0][0]']
#                                 160)
#
#  batch_normalization_515 (Batch  (None, None, None,   480        ['conv2d_515[0][0]']
#  Normalization)                 160)
#
#  activation_515 (Activation)    (None, None, None,   0           ['batch_normalization_515[0][0]']
#                                 160)
#
#  conv2d_511 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_516 (Conv2D)            (None, None, None,   179200      ['activation_515[0][0]']
#                                 160)
#
#  batch_normalization_511 (Batch  (None, None, None,   480        ['conv2d_511[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_516 (Batch  (None, None, None,   480        ['conv2d_516[0][0]']
#  Normalization)                 160)
#
#  activation_511 (Activation)    (None, None, None,   0           ['batch_normalization_511[0][0]']
#                                 160)
#
#  activation_516 (Activation)    (None, None, None,   0           ['batch_normalization_516[0][0]']
#                                 160)
#
#  conv2d_512 (Conv2D)            (None, None, None,   179200      ['activation_511[0][0]']
#                                 160)
#
#  conv2d_517 (Conv2D)            (None, None, None,   179200      ['activation_516[0][0]']
#                                 160)
#
#  batch_normalization_512 (Batch  (None, None, None,   480        ['conv2d_512[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_517 (Batch  (None, None, None,   480        ['conv2d_517[0][0]']
#  Normalization)                 160)
#
#  activation_512 (Activation)    (None, None, None,   0           ['batch_normalization_512[0][0]']
#                                 160)
#
#  activation_517 (Activation)    (None, None, None,   0           ['batch_normalization_517[0][0]']
#                                 160)
#
#  average_pooling2d_49 (AverageP  (None, None, None,   0          ['mixed4[0][0]']
#  ooling2D)                      768)
#
#  conv2d_510 (Conv2D)            (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_513 (Conv2D)            (None, None, None,   215040      ['activation_512[0][0]']
#                                 192)
#
#  conv2d_518 (Conv2D)            (None, None, None,   215040      ['activation_517[0][0]']
#                                 192)
#
#  conv2d_519 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_49[0][0]']
#                                 192)
#
#  batch_normalization_510 (Batch  (None, None, None,   576        ['conv2d_510[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_513 (Batch  (None, None, None,   576        ['conv2d_513[0][0]']
# ...
#
#  conv2d_552 (Conv2D)            (None, None, None,   442368      ['activation_551[0][0]']
#                                 384)
#
#  conv2d_553 (Conv2D)            (None, None, None,   442368      ['activation_551[0][0]']
#                                 384)
#
#  average_pooling2d_52 (AverageP  (None, None, None,   0          ['mixed8[0][0]']
#  ooling2D)                      1280)
#
#  conv2d_546 (Conv2D)            (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_548 (Batch  (None, None, None,   1152       ['conv2d_548[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_549 (Batch  (None, None, None,   1152       ['conv2d_549[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_552 (Batch  (None, None, None,   1152       ['conv2d_552[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_553 (Batch  (None, None, None,   1152       ['conv2d_553[0][0]']
#  Normalization)                 384)
#
#  conv2d_554 (Conv2D)            (None, None, None,   245760      ['average_pooling2d_52[0][0]']
#                                 192)
#
#  batch_normalization_546 (Batch  (None, None, None,   960        ['conv2d_546[0][0]']
#  Normalization)                 320)
#
#  activation_548 (Activation)    (None, None, None,   0           ['batch_normalization_548[0][0]']
#                                 384)
#
#  activation_549 (Activation)    (None, None, None,   0           ['batch_normalization_549[0][0]']
#                                 384)
#
#  activation_552 (Activation)    (None, None, None,   0           ['batch_normalization_552[0][0]']
#                                 384)
#
#  activation_553 (Activation)    (None, None, None,   0           ['batch_normalization_553[0][0]']
#                                 384)
#
#  batch_normalization_554 (Batch  (None, None, None,   576        ['conv2d_554[0][0]']
#  Normalization)                 192)
#
#  activation_546 (Activation)    (None, None, None,   0           ['batch_normalization_546[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_548[0][0]',
#                                 768)                              'activation_549[0][0]']
#
#  concatenate_10 (Concatenate)   (None, None, None,   0           ['activation_552[0][0]',
#                                 768)                              'activation_553[0][0]']
#
#  activation_554 (Activation)    (None, None, None,   0           ['batch_normalization_554[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_546[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate_10[0][0]',
#                                                                   'activation_554[0][0]']
#
#  conv2d_559 (Conv2D)            (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_559 (Batch  (None, None, None,   1344       ['conv2d_559[0][0]']
#  Normalization)                 448)
#
#  activation_559 (Activation)    (None, None, None,   0           ['batch_normalization_559[0][0]']
#                                 448)
#
#  conv2d_556 (Conv2D)            (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_560 (Conv2D)            (None, None, None,   1548288     ['activation_559[0][0]']
#                                 384)
#
#  batch_normalization_556 (Batch  (None, None, None,   1152       ['conv2d_556[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_560 (Batch  (None, None, None,   1152       ['conv2d_560[0][0]']
#  Normalization)                 384)
#
#  activation_556 (Activation)    (None, None, None,   0           ['batch_normalization_556[0][0]']
#                                 384)
#
#  activation_560 (Activation)    (None, None, None,   0           ['batch_normalization_560[0][0]']
#                                 384)
#
#  conv2d_557 (Conv2D)            (None, None, None,   442368      ['activation_556[0][0]']
#                                 384)
#
#  conv2d_558 (Conv2D)            (None, None, None,   442368      ['activation_556[0][0]']
#                                 384)
#
#  conv2d_561 (Conv2D)            (None, None, None,   442368      ['activation_560[0][0]']
#                                 384)
#
#  conv2d_562 (Conv2D)            (None, None, None,   442368      ['activation_560[0][0]']
#                                 384)
#
#  average_pooling2d_53 (AverageP  (None, None, None,   0          ['mixed9[0][0]']
#  ooling2D)                      2048)
#
#  conv2d_555 (Conv2D)            (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_557 (Batch  (None, None, None,   1152       ['conv2d_557[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_558 (Batch  (None, None, None,   1152       ['conv2d_558[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_561 (Batch  (None, None, None,   1152       ['conv2d_561[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_562 (Batch  (None, None, None,   1152       ['conv2d_562[0][0]']
#  Normalization)                 384)
#
#  conv2d_563 (Conv2D)            (None, None, None,   393216      ['average_pooling2d_53[0][0]']
#                                 192)
#
#  batch_normalization_555 (Batch  (None, None, None,   960        ['conv2d_555[0][0]']
#  Normalization)                 320)
#
#  activation_557 (Activation)    (None, None, None,   0           ['batch_normalization_557[0][0]']
#                                 384)
#
#  activation_558 (Activation)    (None, None, None,   0           ['batch_normalization_558[0][0]']
#                                 384)
#
#  activation_561 (Activation)    (None, None, None,   0           ['batch_normalization_561[0][0]']
#                                 384)
#
#  activation_562 (Activation)    (None, None, None,   0           ['batch_normalization_562[0][0]']
#                                 384)
#
#  batch_normalization_563 (Batch  (None, None, None,   576        ['conv2d_563[0][0]']
#  Normalization)                 192)
#
#  activation_555 (Activation)    (None, None, None,   0           ['batch_normalization_555[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_557[0][0]',
#                                 768)                              'activation_558[0][0]']
#
#  concatenate_11 (Concatenate)   (None, None, None,   0           ['activation_561[0][0]',
#                                 768)                              'activation_562[0][0]']
#
#  activation_563 (Activation)    (None, None, None,   0           ['batch_normalization_563[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_555[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_11[0][0]',
#                                                                   'activation_563[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %% [markdown]
# Now that we've loaded the pre-trained InceptionV3 model, we can use it to process the new feature vectors for our LFW dataset. First, we need to reshape the flattend image vector to back into the original image dimensions (125 x 94 x 3).

# %%
# Reshape to be 2D images
X_train_rshp = X_train.reshape([X_train.shape[0], 
                                lfw_people.images.shape[1], 
                                lfw_people.images.shape[2], 
                                lfw_people.images.shape[3]])

X_train_rshp.shape
# Out:
# (901, 125, 94, 3)

# %% [markdown]
# Now we input our images through `base_model` to get the feature vector output. Note that we also apply the `preprocess_input()` function to apply the same preprocessing that was used for pre-training the InceptionV3 model.

# %%
X_train_features = base_model.predict(preprocess_input(X_train_rshp))
# Out:
# 29/29 [==============================] - 26s 879ms/step

# %% [markdown]
# The dimensions of each sample output by the model are 1 x 1 x 2048 (2048 features), so we will reshape these feature vectors to remove the 1x1 dimension. The result is a dataset of 2048-dimensional feature vectors, one for each of our 901 training samples.

# %%
X_train_features.shape
# Out:
# (901, 2, 1, 2048)

# %%
X_train_features = X_train_features[:,0,0]

X_train_features.shape
# Out:
# (901, 2048)

# %% [markdown]
# ### SVM classifier with InceptionV3 features
#
# Now that we've extracted new features using InceptionV3, we can use these new features as our inputs for classification. In this example, we'll use a Support Vector Machine (SVM) classifier. In the cell below, train an SVM with `C=10000` and `kernel='rbf'` as we did in Labs 11-12.

# %%
# YOUR CODE HERE
from sklearn.svm import SVC

svm = SVC(C= 10000,kernel='rbf')

# %% [markdown]
# In the cell(s) below, use the trained model to extract the InceptionV3 feature vectors for the test set. Note that you will have to reshape the test data and the output features in the same way we did for the training data.

# %%
# YOUR CODE HERE
X_test_reshape = X_test.reshape([X_test.shape[0], 
                                lfw_people.images.shape[1], 
                                lfw_people.images.shape[2], 
                                lfw_people.images.shape[3]])

print(X_test_reshape.shape)

X_test_features = base_model.predict(preprocess_input(X_test_reshape))
# Out:
# (387, 125, 94, 3)
# 13/13 [==============================] - 11s 809ms/step

# %%
X_test_features = X_test_features[:,0,0]

# %% [markdown]
# Now that you've extracted the InceptionV3 features for the test dataset, you can use the SVM classifier to make predictions for the test set based on these feature vectors. Do this in the cell below and store your predictions in a variable named `y_pred`.

# %%
# YOUR CODE HERE
svm.fit(X_train_features,y_train)

y_pred = svm.predict(X_test_features)

# %% [markdown]
# The next cell shows how we can use the `classification_report()` function in sklearn to print several metrics computed for the test set.

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.45      0.56      0.50        18
#      Colin Powell       0.75      0.78      0.77        69
#   Donald Rumsfeld       0.67      0.53      0.59        34
#     George W Bush       0.74      0.88      0.80       166
# Gerhard Schroeder       0.35      0.29      0.32        31
#       Hugo Chavez       0.71      0.26      0.38        19
#        Tony Blair       0.63      0.44      0.52        50
#
#          accuracy                           0.68       387
#         macro avg       0.61      0.53      0.55       387
#      weighted avg       0.67      0.68      0.67       387

# %% [markdown]
# We can also use the `ConfusionMatrixDisplay` object to visualize the confusion matrix for the test set predictions.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(
    svm, X_test_features, y_test, display_labels=target_names, xticks_rotation="vertical"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Question 1: Compare the results from the SVM with InceptionV3 features to the results from KernelPCA in Lab 12 and linear PCA in Lab 11. How do the results differ?**
#
# **Answer:**
#
# SVM with InceptionV3(0.68 accuracy) is more accurate than linearPCA in Lab11(0.48 accuracy) followed by Kernel PCA in Lab12(0.41 accuracy)

# %% [markdown]
# ## Fine-tune pre-trained network for face classification
#
# One way to increase performance even further is to "fine-tune" the InceptionV3 model for our new classification task by adding a new classification layer to the end of the network and optionally unfreezing some of the later layers in the network.
#
# In the cells below, we load our InceptionV3 pre-trained base model in the same way we did in the first exercise.

# %%
import tensorflow as tf
tf.config.run_functions_eagerly(True)

from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
pre_trained_model = InceptionV3(
    input_shape=(lfw_people.images.shape[1], lfw_people.images.shape[2], 3), include_top=False, weights='imagenet')

# %% [markdown]
# For this exercise, we'll freeze all of the layers in the original InceptionV3 model by setting the `trainable` attribute of each layer to `False`.

# %%
for layer in pre_trained_model.layers:
    layer.trainable = False

# %% [markdown]
# We then truncate the pre-trained model at one of the deeper hidden layers and append new layers, including our new classification layer for our LFW face classes, to the end.

# %%
last_layer = pre_trained_model.get_layer('mixed7')

print('last layer output shape:', last_layer.output_shape)

last_output = last_layer.output
# Out:
# last layer output shape: (None, 6, 4, 768)

# %%
# Flatten the output layer to 1 dimension
x = layers.Flatten()(last_output)

# Add a fully connected layer with 1,024 hidden units and ReLU activation
x = layers.Dense(1024, activation='relu')(x)

# Add a dropout rate of 0.2
x = layers.Dropout(0.2)(x)

# Add a final sigmoid layer for classification
x = layers.Dense(len(target_names), activation='sigmoid')(x)

# %% [markdown]
# We now compile the new model.

# %%
# Configure and compile the model
model = Model(pre_trained_model.input, x)
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['acc'])

# %% [markdown]
# Next, we can use our LFW training data and labels to fine-tune the model. Note that first we need to convert our labels to a 1-hot encoding.

# %%
# Convert labels to one-hot encoding
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=len(target_names))

# %%
model.fit(x=X_train_rshp, y=y_train_cat,
                epochs=10,
                batch_size=32,
                shuffle=True)
# Out:
# Epoch 1/10
# 29/29 [==============================] - 104s 4s/step - loss: 2.1992 - acc: 0.4107
# Epoch 2/10
# 29/29 [==============================] - 103s 4s/step - loss: 1.3944 - acc: 0.5161
# Epoch 3/10
# 29/29 [==============================] - 104s 4s/step - loss: 1.3893 - acc: 0.5427
# Epoch 4/10
# 29/29 [==============================] - 107s 4s/step - loss: 1.1151 - acc: 0.6393
# Epoch 5/10
# 29/29 [==============================] - 107s 4s/step - loss: 1.0508 - acc: 0.6448
# Epoch 6/10
# 29/29 [==============================] - 102s 4s/step - loss: 0.9921 - acc: 0.6670
# Epoch 7/10
# 29/29 [==============================] - 102s 4s/step - loss: 0.8925 - acc: 0.7014
# Epoch 8/10
# 29/29 [==============================] - 103s 4s/step - loss: 0.8894 - acc: 0.7192
# Epoch 9/10
# 29/29 [==============================] - 102s 4s/step - loss: 0.8921 - acc: 0.6970
# Epoch 10/10
# 29/29 [==============================] - 102s 4s/step - loss: 0.7364 - acc: 0.7703

# %% [markdown]
# Now that we've fine-tuned our model, we can use it to make predictions about our test set. Use the trained model to make predictions for the test dataset in the cell(s) below. Remember to convert the test labels to a 1-hot encoding as we did for training. As in the first exercise, store the predictions in a variable called `y_pred`.

# %%
# YOUR CODE HERE
y_pred = model.predict(X_test_reshape)
# Out:
# 13/13 [==============================] - 10s 739ms/step

# %% [markdown]
# The `predict()` function returns the class probabilities output by the model for each of the 7 classes. To get the index of the predicted class, we can use the `np.argmax()` function to get the index with the highest class probability.

# %%
y_pred_class = np.argmax(y_pred, axis=1)

# %% [markdown]
# Now that we have an array of the predicted classes for the test set, we can compute the performance metrics as in the first exercise. In the cell below, print the classification report for the test set.

# %%
# YOUR CODE HERE
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_class, target_names=target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.13      0.94      0.22        18
#      Colin Powell       0.87      0.86      0.86        69
#   Donald Rumsfeld       0.91      0.29      0.44        34
#     George W Bush       0.86      0.89      0.88       166
# Gerhard Schroeder       0.00      0.00      0.00        31
#       Hugo Chavez       0.67      0.11      0.18        19
#        Tony Blair       0.00      0.00      0.00        50
#
#          accuracy                           0.61       387
#         macro avg       0.49      0.44      0.37       387
#      weighted avg       0.64      0.61      0.59       387

# %% [markdown]
# **Question 2: Compare the results from the fine-tuned network to the SVM with InceptionV3 features from the first exercise. How do the results differ?**
#
# **Answer:**
# Compared to InceptionV3 with SVM, InceptionV3 Fine-tuned network has much worse precision, recall, f1-score, and accuracy. There are classes with no scores.

# %% [markdown]
# **Question 3: What are some reasons that might explain the difference in performance between the fine-tuned network and the SVM with InceptionV3 features?**
#
# **Answer:**
#
# Finetuned network performs less better than inceptionV3 because for the finetuned model we might have less no of samples, less epochs ,relatively less class labels and we might be overtraining the model by adding finetuning(as it adds another classification layer in the end) and also in the classification report we can see that some labels have f1-score, precision set to zero as there are no predicted samples.
