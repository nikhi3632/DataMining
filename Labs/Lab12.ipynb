# %% [markdown]
# # CSE 572: Lab 12
#
# In this lab, you will practice implementing techniques for dimensionality reduction using Kernel PCA and autoencoder neural networks.
#
# To execute and make changes to this notebook, click File > Save a copy to save your own version in your Google Drive or Github. Read the step-by-step instructions below carefully. To execute the code, click on each cell below and press the SHIFT-ENTER keys simultaneously or by clicking the Play button.
#
# When you finish executing all code/exercises, save your notebook then download a copy (.ipynb file). Submit the following **three** things:
# 1. a link to your Colab notebook,
# 2. the .ipynb file, and
# 3. a pdf of the executed notebook on Canvas.
#
# To generate a pdf of the notebook, click File > Print > Save as PDF.

# %% [markdown]
# ## Kernel PCA
#
# Principal component analysis (PCA) is a classical method for reducing the dimensionality (number of attributes) in the data by projecting the data from its original high-dimensional space into a lower-dimensional space. The conventional formulation of PCA is limited to finding a linear projection of the data, so if the original data are not linearly separable then the PCA-projected data also will not be. Kernel PCA is a simple modification of PCA that uses kernel functions to project data into a higher-dimensional space where it may become linearly separable and compute PCA in the higher-dimensional space, using special kernel functions to make this computation feasible.
#
# In this section, we will apply Kernel PCA to the same image dataset from Lab 11 and compare the results to linear PCA.

# %% [markdown]
# ### Load the dataset
#
# We will use a preprocessed subset of the “Labeled Faces in the Wild” (LFW) dataset, which you can read more about [here](http://vis-www.cs.umass.edu/lfw/).

# %%
from sklearn.datasets import fetch_lfw_people

lfw_people = fetch_lfw_people(min_faces_per_person=70)

# data attribute gives the data matrix with the image dimension flattened
X = lfw_people.data
print('Num samples: {}'.format(X.shape[0]))
print('Num features: {}'.format(X.shape[1]))

# images attribute gives the unflattened image dimension
print('Image dimensions: {} x {}'.format(lfw_people.images.shape[1], lfw_people.images.shape[2]))

# the label to predict is the id of the person
y = lfw_people.target
# target_names attribute tells us the name of the person associated with each id
target_names = lfw_people.target_names
n_classes = target_names.shape[0]
print('Num classes: {}'.format(n_classes))
print('Class names:', target_names)
# Out:
# Num samples: 1288
# Num features: 2914
# Image dimensions: 62 x 47
# Num classes: 7
# Class names: ['Ariel Sharon' 'Colin Powell' 'Donald Rumsfeld' 'George W Bush'
#  'Gerhard Schroeder' 'Hugo Chavez' 'Tony Blair']

# %% [markdown]
# The dataset has 1,288 images of the faces of 7 different people. The code below prints the number of samples from each class.

# %%
for i in range(n_classes):
    print('Number of instances in class {} ({}): {}'.format(i,
                                                            target_names[i],
                                                            y[y==i].shape[0]
                                                           ))
# Out:
# Number of instances in class 0 (Ariel Sharon): 77
# Number of instances in class 1 (Colin Powell): 236
# Number of instances in class 2 (Donald Rumsfeld): 121
# Number of instances in class 3 (George W Bush): 530
# Number of instances in class 4 (Gerhard Schroeder): 109
# Number of instances in class 5 (Hugo Chavez): 71
# Number of instances in class 6 (Tony Blair): 144

# %% [markdown]
# To get an idea of what is in our dataset, we visualize a random face from each class below. (Note: You can run this cell many times to see different random examples.)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(ncols=n_classes, figsize=(13,6))

for i in range(n_classes):
    rand_ind = np.random.randint(0, y[y==i].shape[0])
    axes[i].imshow(lfw_people.images[y==i][rand_ind], cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(target_names[i])

# %% [markdown]
# Next, we will split the data into training and test subsets, using 30\% of the data for testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# Next we standardize the data so that the mean of all attributes is 0 using the StandardScaler() object in scikit-learn to standardize the data. We fit the scaler to the training data and apply it to both the training and test data.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Kernel PCA
#
# Kernel PCA uses one of several choices of kernel functions to transform the data into a higher-dimensinoal space and then compute the principal components (eigenvectors) of the data in the high-D space. We then use these principal components to transform the data into a new set of features that maximizes variance in the dataset.
#
# The KernelPCA class in scikit-learn gives four options for kernel functions (the same functions available for SVM): 'poly', 'rbf', 'sigmoid', and 'cosine'. In the code below, we implement KernelPCA using 10 principal components and the RBF kernel.

# %%
from sklearn.decomposition import KernelPCA

n_components = 10

kpca = KernelPCA(n_components=n_components, kernel='rbf', fit_inverse_transform=True).fit(X_train)

# %% [markdown]
# We can use our PCA model (i.e., the principal component vectors found in our data) to transform our dataset into the new reduced-dimensional space. This is done in the below code using the `transform()` function.

# %%
X_train_kpca = kpca.transform(X_train)
X_test_kpca = kpca.transform(X_test)

# %% [markdown]
# We now have a 10-dimensional version of our dataset. This is much smaller than the original 2914 dimensions! We can visualize the data in the first two component dimensions using a scatter plot, colored by class to see the differences between classes.

# %%
fig, ax = plt.subplots(1)

for i in range(n_classes):
    ax.scatter(X_train_kpca[y_train==i][:,0], X_train_kpca[y_train==i][:,1], label=target_names[i], alpha=0.5)
    
ax.set_xlabel('PC 1')
ax.set_xlabel('PC 2')
ax.legend()

# %% [markdown]
# ### SVM classifier with Kernel PCA
#
# Now that we've reduced the dimensionality of our dataset from 2914 to 10, we can use these new features as our inputs for classification. In this example, we'll use a Support Vector Machine (SVM) classifier. In the cell below, train an SVM with `C=10000` and `kernel='rbf'`.

# %%
from sklearn.svm import SVC

clf = SVC(C=10000, kernel='rbf')
clf = clf.fit(X_train_kpca, y_train)

# %% [markdown]
# In the cell below, use the trained model to make predictions for the test set.

# %%
y_pred = clf.predict(X_test_kpca)

# %% [markdown]
# The next cell shows how we can use the `classification_report()` function in sklearn to print several metrics computed for the test set.

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.09      0.11      0.10        18
#      Colin Powell       0.30      0.43      0.35        69
#   Donald Rumsfeld       0.25      0.32      0.28        34
#     George W Bush       0.67      0.62      0.64       166
# Gerhard Schroeder       0.25      0.16      0.20        31
#       Hugo Chavez       0.10      0.11      0.10        19
#        Tony Blair       0.24      0.12      0.16        50
#
#          accuracy                           0.41       387
#         macro avg       0.27      0.27      0.26       387
#      weighted avg       0.42      0.41      0.41       387

# %% [markdown]
# We can also use the `ConfusionMatrixDisplay` object to visualize the confusion matrix for the test set predictions.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(
    clf, X_test_kpca, y_test, display_labels=target_names, xticks_rotation="vertical"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Question 1: Compare the results from KernelPCA to the results from PCA in Lab 11. How do the results differ?**
#
# **Answer:**
#
# Accuracy of PCA in Lab 11(0.48) is greater than kpca above(0.41)
#
# F1-score, Precision and Recall are higher for PCA in Lab 11 than the above kernelPCA for each of the labels.
#
# The Linear subspace dimensionality works better in for the given dataset.

# %% [markdown]
# **Question 2: What is the difference between the covariance matrix and the confusion matrix? What are the dimensions of each in terms of the number of attributes (m) and the number of classes (c)? How are each used here?**
#
# **Answer:**
#
# m = Number of Attributes, c = Number of Classes
#
# Covariance Matrix computes the variance between each pair of attributes.(i.e how an attribute varies with another) while Confusion Matrix compares the number true label of each class with predicted label of each other class.
#
# Confusion Matrix is c by c dimensions and Covariance Matrix is m by m dimensions.
#
# Here Confusion Matrix is 7 by 7 matrix and Covariance Matrix is 10 by 10 (for pca with 10 components).

# %% [markdown]
# ### Data reconstruction
#
# We can reconstruct the original input images by multiplying the encoded data in the principal subspace by the principal component vectors. This reverse transformation is called the *inverse transform*. The code below reconstructs the original data using the KernelPCA `inverse_transform()` function.

# %%
train_recon_kpca = kpca.inverse_transform(X_train_kpca)
test_recon_kpca = kpca.inverse_transform(X_test_kpca)

# %% [markdown]
# Create a plot to visualize the original image and reconstructed image for the first 5 images in the test set. Plot the original images on the first row and the reconstructions on the second row. Print the class name as the title for each original image and turn off the axis labels/tickmarks (as in the earlier face visualization from this lab).

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(10,5))
n_images = 5

# YOUR CODE HERE
for i in range(n_images):
  axes[0,i].imshow(np.reshape(X_test[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')
  axes[1,i].imshow(np.reshape(test_recon_kpca[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')

  axes[0,i].set_title(target_names[y_test[i]])
  axes[1,i].set_title(target_names[y_test[i]])
  axes[0,i].axis('off')
  axes[1,i].axis('off')

# %% [markdown]
# In Lab 11, we used linear PCA to reduce the data dimensionality and use the transformed data as the input to SVM as we did in Lab 12 with KernelPCA. However, in Lab 11 we did not reconstruct the original data from the principal subspace as we did above with KernelPCA.
#
# In the cell(s) below, fit a new linear PCA model with 10 principal components (same as was done in Lab 11). Then, plot the above visualization again, but this time add a third row for the same images reconstructed using linear PCA.

# %%
# YOUR CODE HERE
from sklearn.decomposition import PCA

n_components = 10

pca = PCA(n_components=n_components).fit(X_train)

X_train_linear_pca = pca.transform(X_train)
X_test_linear_pca = pca.transform(X_test)


clf = SVC(C=10000, kernel='rbf')
clf = clf.fit(X_train_linear_pca, y_train)

y_pred_lpca = clf.predict(X_test_linear_pca)

train_recon_lpca = pca.inverse_transform(X_train_linear_pca)
test_recon_lpca = pca.inverse_transform(X_test_linear_pca)

# %%
# YOUR CODE HERE
fig, axes = plt.subplots(ncols=5, nrows=3, figsize=(10,5))
n_images = 5

for i in range(n_images):
  axes[0,i].imshow(np.reshape(X_test[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')
  axes[1,i].imshow(np.reshape(test_recon_kpca[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')
  axes[2,i].imshow(np.reshape(test_recon_lpca[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')

  axes[0,i].set_title(target_names[y_test[i]])
  axes[1,i].set_title(target_names[y_test[i]])
  axes[2,i].set_title(target_names[y_test[i]])
  axes[0,i].axis('off')
  axes[1,i].axis('off')
  axes[2,i].axis('off')

# %% [markdown]
# ## Autoencoder neural network
#
# An autoencoder is a type of neural network in which the outputs are the same as the inputs. In other words, the goal of the network is to reconstruct the original input image by minimizing the mean squared error loss function. The autoencoder consists of two main components: an encoder network that maps the input data to a low dimensional representation $z$ and a decoder network that maps $z$ back to the original dimension.
#
# In the code below, we implement a simple autoencoder network using dense (feed-forward) layers and train it using our LFW faces dataset.

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  

# This is our input image
input_img = keras.Input(shape=(X_train.shape[1],))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(encoding_dim, activation='relu')(encoded)

# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(X_train.shape[1], activation='sigmoid')(decoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %% [markdown]
# In addition to the full autoencoder model, we can construct the encoder and decoder models separately. Here we will construct the encoder model so that we can use it to reduce the data dimensionality without having to also reconstruct the data (which is done by `autoencoder`).

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %% [markdown]
# Next we compile the model. We'll use the Adam optimizer and mean squared error loss.

# %%
autoencoder.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Now we train our model. Below we train for 300 epochs using a batch size of 32.

# %%
autoencoder.fit(x=X_train, y=X_train,
                epochs=300,
                batch_size=32,
                shuffle=True)
# Out:
# Epoch 1/300
# 29/29 [==============================] - 1s 12ms/step - loss: 0.9962
# Epoch 2/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.8812
# Epoch 3/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.8283
# Epoch 4/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.8022
# Epoch 5/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.7853
# Epoch 6/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7726
# Epoch 7/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.7644
# Epoch 8/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7570
# Epoch 9/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7511
# Epoch 10/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.7429
# Epoch 11/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.7381
# Epoch 12/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7321
# Epoch 13/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7277
# Epoch 14/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7242
# Epoch 15/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7196
# Epoch 16/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.7182
# Epoch 17/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7142
# Epoch 18/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7105
# Epoch 19/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.7092
# Epoch 20/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.7060
# Epoch 21/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.7018
# Epoch 22/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6988
# Epoch 23/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6963
# Epoch 24/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6949
# Epoch 25/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6928
# Epoch 26/300
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6910
# Epoch 27/300
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6881
# Epoch 28/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6862
# Epoch 29/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6846
# Epoch 30/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6837
# Epoch 31/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6816
# Epoch 32/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6797
# Epoch 33/300
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6789
# Epoch 34/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6774
# Epoch 35/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6760
# Epoch 36/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6741
# Epoch 37/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6740
# Epoch 38/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6725
# Epoch 39/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6713
# Epoch 40/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6707
# Epoch 41/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6694
# Epoch 42/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6682
# Epoch 43/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6681
# Epoch 44/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6683
# Epoch 45/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6665
# Epoch 46/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6654
# Epoch 47/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6637
# Epoch 48/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6625
# Epoch 49/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6617
# Epoch 50/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6611
# Epoch 51/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6597
# Epoch 52/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6588
# Epoch 53/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6577
# Epoch 54/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6588
# Epoch 55/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6583
# Epoch 56/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6569
# Epoch 57/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6567
# Epoch 58/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6561
# Epoch 59/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6557
# Epoch 60/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6552
# Epoch 61/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6549
# Epoch 62/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6541
# Epoch 63/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6538
# Epoch 64/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6540
# Epoch 65/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6535
# Epoch 66/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6529
# Epoch 67/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6514
# Epoch 68/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6516
# Epoch 69/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6517
# Epoch 70/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6506
# Epoch 71/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6556
# Epoch 72/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6538
# Epoch 73/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6517
# Epoch 74/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6499
# Epoch 75/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6510
# Epoch 76/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6493
# Epoch 77/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6487
# Epoch 78/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6474
# Epoch 79/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6464
# Epoch 80/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6459
# Epoch 81/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6456
# Epoch 82/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6456
# Epoch 83/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6465
# Epoch 84/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6466
# Epoch 85/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6456
# Epoch 86/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6455
# Epoch 87/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6471
# Epoch 88/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6471
# Epoch 89/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6455
# Epoch 90/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6440
# Epoch 91/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6433
# Epoch 92/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6428
# Epoch 93/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6424
# Epoch 94/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6423
# Epoch 95/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6419
# Epoch 96/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6411
# Epoch 97/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6409
# Epoch 98/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6411
# Epoch 99/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6410
# Epoch 100/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6410
# Epoch 101/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6420
# Epoch 102/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6414
# Epoch 103/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6406
# Epoch 104/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6410
# Epoch 105/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6408
# Epoch 106/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6410
# Epoch 107/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6409
# Epoch 108/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6406
# Epoch 109/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6397
# Epoch 110/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6396
# Epoch 111/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6388
# Epoch 112/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6379
# Epoch 113/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6387
# Epoch 114/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6386
# Epoch 115/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6381
# Epoch 116/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6383
# Epoch 117/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6383
# Epoch 118/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6380
# Epoch 119/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6380
# Epoch 120/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6389
# Epoch 121/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6380
# Epoch 122/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6374
# Epoch 123/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6366
# Epoch 124/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6360
# Epoch 125/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6378
# Epoch 126/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6374
# Epoch 127/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6378
# Epoch 128/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6377
# Epoch 129/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6380
# Epoch 130/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6373
# Epoch 131/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6426
# Epoch 132/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6408
# Epoch 133/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6394
# Epoch 134/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6380
# Epoch 135/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6362
# Epoch 136/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6359
# Epoch 137/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6345
# Epoch 138/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6341
# Epoch 139/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6336
# Epoch 140/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6331
# Epoch 141/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6331
# Epoch 142/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6332
# Epoch 143/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6332
# Epoch 144/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6331
# Epoch 145/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6332
# Epoch 146/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6342
# Epoch 147/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6343
# Epoch 148/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6337
# Epoch 149/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6339
# Epoch 150/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6341
# Epoch 151/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6338
# Epoch 152/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6334
# Epoch 153/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6338
# Epoch 154/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6336
# Epoch 155/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6333
# Epoch 156/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6328
# Epoch 157/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6334
# Epoch 158/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6340
# Epoch 159/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6339
# Epoch 160/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6338
# Epoch 161/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6338
# Epoch 162/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6341
# Epoch 163/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6343
# Epoch 164/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6334
# Epoch 165/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6330
# Epoch 166/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6322
# Epoch 167/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6319
# Epoch 168/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6325
# Epoch 169/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6327
# Epoch 170/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6328
# Epoch 171/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6329
# Epoch 172/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6335
# Epoch 173/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6337
# Epoch 174/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6331
# Epoch 175/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6344
# Epoch 176/300
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6327
# Epoch 177/300
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6323
# Epoch 178/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6317
# Epoch 179/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6311
# Epoch 180/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6308
# Epoch 181/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6300
# Epoch 182/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6295
# Epoch 183/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6296
# Epoch 184/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6299
# Epoch 185/300
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6303
# Epoch 186/300
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6303
# Epoch 187/300
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6304
# Epoch 188/300
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6309
# Epoch 189/300
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6308
# Epoch 190/300
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6307
# Epoch 191/300
# 29/29 [==============================] - 1s 17ms/step - loss: 0.6306
# Epoch 192/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6311
# Epoch 193/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6311
# Epoch 194/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6326
# Epoch 195/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6318
# Epoch 196/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6315
# Epoch 197/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6319
# Epoch 198/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6316
# Epoch 199/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6308
# Epoch 200/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6298
# Epoch 201/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6295
# Epoch 202/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6295
# Epoch 203/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6296
# Epoch 204/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6295
# Epoch 205/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6299
# Epoch 206/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6314
# Epoch 207/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6318
# Epoch 208/300
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6331
# Epoch 209/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6326
# Epoch 210/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6324
# Epoch 211/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6316
# Epoch 212/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6313
# Epoch 213/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6298
# Epoch 214/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6287
# Epoch 215/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6283
# Epoch 216/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6282
# Epoch 217/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6279
# Epoch 218/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6276
# Epoch 219/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6274
# Epoch 220/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6282
# Epoch 221/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6287
# Epoch 222/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6291
# Epoch 223/300
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6291
# Epoch 224/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6290
# Epoch 225/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6282
# Epoch 226/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6284
# Epoch 227/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6283
# Epoch 228/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6280
# Epoch 229/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6280
# Epoch 230/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6283
# Epoch 231/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6290
# Epoch 232/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6292
# Epoch 233/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6304
# Epoch 234/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6295
# Epoch 235/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6289
# Epoch 236/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6288
# Epoch 237/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6299
# Epoch 238/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6296
# Epoch 239/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6301
# Epoch 240/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6297
# Epoch 241/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6309
# Epoch 242/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6309
# Epoch 243/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6293
# Epoch 244/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6283
# Epoch 245/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6279
# Epoch 246/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6276
# Epoch 247/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6276
# Epoch 248/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6277
# Epoch 249/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6279
# Epoch 250/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6280
# Epoch 251/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6277
# Epoch 252/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6275
# Epoch 253/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6273
# Epoch 254/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6278
# Epoch 255/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6280
# Epoch 256/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6283
# Epoch 257/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6278
# Epoch 258/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6280
# Epoch 259/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6274
# Epoch 260/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6268
# Epoch 261/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6269
# Epoch 262/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6274
# Epoch 263/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6280
# Epoch 264/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6278
# Epoch 265/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6278
# Epoch 266/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6291
# Epoch 267/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6276
# Epoch 268/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6269
# Epoch 269/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6275
# Epoch 270/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6273
# Epoch 271/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6280
# Epoch 272/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6275
# Epoch 273/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6280
# Epoch 274/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6282
# Epoch 275/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6296
# Epoch 276/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6296
# Epoch 277/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6287
# Epoch 278/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6271
# Epoch 279/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6267
# Epoch 280/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6267
# Epoch 281/300
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6266
# Epoch 282/300
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6261
# Epoch 283/300
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6255
# Epoch 284/300
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6251
# Epoch 285/300
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6251
# Epoch 286/300
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6247
# Epoch 287/300
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6246
# Epoch 288/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6248
# Epoch 289/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6249
# Epoch 290/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6256
# Epoch 291/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6256
# Epoch 292/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6253
# Epoch 293/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6249
# Epoch 294/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6247
# Epoch 295/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6242
# Epoch 296/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6245
# Epoch 297/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6248
# Epoch 298/300
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6252
# Epoch 299/300
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6301
# Epoch 300/300
#  5/29 [====>.........................] - ETA: 0s - loss: 0.5641

# %% [markdown]
# **Question 3: In the code above, why did we set x and y both equal to `X_train`?**
#
# **Answer:**
#
# In order to train the autoencoder model using X-train as both input(x) and target(y) because the decoder needs to reconstuct the image sent by the encoder so we set X_train as target.

# %% [markdown]
# Now we have our trained autoencoder for which the input is an image and the output is the reconstruction. Next we use our trained autoencoder to reconstruct the test images.

# %%
test_recon_ae = autoencoder.predict(X_test)

# %% [markdown]
# In the cell below, visualize the same 5 as we did for KernelPCA and linear PCA. You can copy the same code as the previous code block used for visualization and add a fourth row for the autoencoder reconstructions.

# %%
# YOUR CODE HERE
fig, axes = plt.subplots(ncols=5, nrows=4, figsize=(10,5))
n_images = 5

for i in range(n_images):
  axes[0,i].imshow(np.reshape(X_test[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')
  axes[1,i].imshow(np.reshape(test_recon_kpca[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')
  axes[2,i].imshow(np.reshape(test_recon_lpca[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')
  axes[3,i].imshow(np.reshape(test_recon_ae[i],[lfw_people.images.shape[1],lfw_people.images.shape[2]]),cmap= 'gray')

  axes[0,i].set_title(target_names[y_test[i]])
  axes[1,i].set_title(target_names[y_test[i]])
  axes[2,i].set_title(target_names[y_test[i]])
  axes[3,i].set_title(target_names[y_test[i]])
  axes[0,i].axis('off')
  axes[1,i].axis('off')
  axes[2,i].axis('off')
  axes[3,i].axis('off')

# %% [markdown]
# **Question 4: The reconstructions by the autoencoder do not look as accurate as the reconstructions by the PCA and KernelPCA models. This does not mean that linear or kernel PCA is inherently better than an autoencoder for reducing the dimensionality of this dataset---it is probable that if we spent time tuning all the hyperparameters of the autoencoder, we would find a model that has a better solution. However, there are many more hyperparameters to tune in the autoencoder compared to the PCA models. List at least three hyperparameters that could be optimized for the autoencoder.**
#
# **Answer:**
#
# Batch size, Loss function, Optimizer Type, Number of Layers.

# %% [markdown]
# **Question 5: The autoencoder we implemented here used feed-forward/dense layers. Another way to improve the autoencoder reconstruction could be to use a different type of layer. What other type of layer might give better performance (e.g., convolutional, recurrent) and why?**
#
# **Answer:**
#
# Convolutional Layer works better for autoencoder reconstruction with images as their design prevents too much loss of information and works better for noise reduction as it does not slice off information completely in the next layers. Convolutional layers would be better because we are using image data, which is more suitable for convolutional neural networks which learn spatial filters for extracting hidden representations.
